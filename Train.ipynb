# %%
# !pip install wandb -qqq
import wandb
wandb.login()
# Out:
# True

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.5/857.5 MB 2.8 MB/s eta 0:00:0000:0100:02
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 15.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 15.3 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached https://download.pytorch.org/whl/cu118/nvidia_cuda_nvrtc_cu11-11.8.89-py3-none-manylinux1_x86_64.whl (23.2 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu118/nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux1_x86_64.whl (875 kB)
# ...
#   Using cached https://download.pytorch.org/whl/cu118/nvidia_cuda_cupti_cu11-11.8.87-py3-none-manylinux1_x86_64.whl (13.1 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu118/nvidia_cudnn_cu11-9.1.0.70-py3-none-manylinux2014_x86_64.whl (663.9 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu118/nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux1_x86_64.whl (417.9 MB)
# ...

# %%
# !python3 main.py --epochs 300 --lr 0.001 --patience 10 --min_delta 0.001 --loss_function CrossEntropyLoss --mode train
# Out:
# wandb: Currently logged in as: arthur12137. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /mnt/vos-9k0sd0n7/will/bowen_workplace/Oil_Seep_Test/wandb/run-20241011_041201-bf7kv785
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run rose-forest-101
# wandb: ⭐️ View project at https://wandb.ai/arthur12137/unet-seep-detection
# wandb: 🚀 View run at https://wandb.ai/arthur12137/unet-seep-detection/runs/bf7kv785
# INFO:root:[EPOCH 1] Train Loss: 0.9475 | Dice: 0.0266 | IoU: 0.0089 | Precision: 0.8020 | Recall: 0.2665 | F1: 0.0185 | Accuracy: 0.9084
# [EPOCH 1] Train Loss: 0.9475 | Dice: 0.0266 | IoU: 0.0089 | Precision: 0.8020 | Recall: 0.2665 | F1: 0.0185 | Accuracy: 0.9084
# INFO:root:[EPOCH 1] Valid Loss: 0.4881 | Dice: 0.0024 | IoU: 0.0024 | Precision: 1.0000 | Recall: 0.0024 | F1: 0.0024 | Accuracy: 0.9834
# ...

# %%
# !python main.py --epochs 300 --lr 0.001 --patience 10 --min_delta 0.001 --loss_function DiceLoss --mode train
# Out:
# wandb: Currently logged in as: arthur12137. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /mnt/vos-9k0sd0n7/will/bowen_workplace/Oil_Seep_Test/wandb/run-20241011_041946-4oilhaxy
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run magic-jazz-102
# wandb: ⭐️ View project at https://wandb.ai/arthur12137/unet-seep-detection
# wandb: 🚀 View run at https://wandb.ai/arthur12137/unet-seep-detection/runs/4oilhaxy
# INFO:root:[EPOCH 1] Train Loss: 0.9199 | Dice: 0.1779 | IoU: 0.0507 | Precision: 0.6008 | Recall: 0.4020 | F1: 0.1051 | Accuracy: 0.8667
# [EPOCH 1] Train Loss: 0.9199 | Dice: 0.1779 | IoU: 0.0507 | Precision: 0.6008 | Recall: 0.4020 | F1: 0.1051 | Accuracy: 0.8667
# INFO:root:[EPOCH 1] Valid Loss: 0.8872 | Dice: 0.0136 | IoU: 0.0087 | Precision: 0.9860 | Recall: 0.0107 | F1: 0.0092 | Accuracy: 0.9270
# ...

# %%
# !python main.py --epochs 300 --lr 0.001 --patience 10 --min_delta 0.001 --loss_function IoULoss --mode train
# Out:
# wandb: Currently logged in as: arthur12137. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /mnt/vos-9k0sd0n7/will/bowen_workplace/Oil_Seep_Test/wandb/run-20241011_043037-fot7rcju
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run brisk-sun-107
# wandb: ⭐️ View project at https://wandb.ai/arthur12137/unet-seep-detection
# wandb: 🚀 View run at https://wandb.ai/arthur12137/unet-seep-detection/runs/fot7rcju
# INFO:root:[EPOCH 1] Train Loss: 0.9400 | Dice: 0.1230 | IoU: 0.0892 | Precision: 0.6686 | Recall: 0.7473 | F1: 0.0822 | Accuracy: 0.7613
# [EPOCH 1] Train Loss: 0.9400 | Dice: 0.1230 | IoU: 0.0892 | Precision: 0.6686 | Recall: 0.7473 | F1: 0.0822 | Accuracy: 0.7613
# INFO:root:[EPOCH 1] Valid Loss: 0.9173 | Dice: 0.0027 | IoU: 0.0024 | Precision: 0.8521 | Recall: 0.0045 | F1: 0.0022 | Accuracy: 0.9261
# ...

# %%
# !python main.py --epochs 300 --lr 0.001 --patience 10 --min_delta 0.001 --loss_function FocalLoss --mode train
# Out:
# wandb: Currently logged in as: arthur12137. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /mnt/vos-9k0sd0n7/will/bowen_workplace/Oil_Seep_Test/wandb/run-20241011_043951-hsqscdao
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run peachy-flower-112
# wandb: ⭐️ View project at https://wandb.ai/arthur12137/unet-seep-detection
# wandb: 🚀 View run at https://wandb.ai/arthur12137/unet-seep-detection/runs/hsqscdao
# INFO:root:[EPOCH 1] Train Loss: 1.2060 | Dice: 0.1508 | IoU: 0.0682 | Precision: 0.7487 | Recall: 0.5772 | F1: 0.1035 | Accuracy: 0.8599
# [EPOCH 1] Train Loss: 1.2060 | Dice: 0.1508 | IoU: 0.0682 | Precision: 0.7487 | Recall: 0.5772 | F1: 0.1035 | Accuracy: 0.8599
# INFO:root:[EPOCH 1] Valid Loss: 0.9661 | Dice: 0.0074 | IoU: 0.0055 | Precision: 0.8654 | Recall: 0.0194 | F1: 0.0050 | Accuracy: 0.9256
# ...

# %%
# !python main.py --epochs 300 --lr 0.001 --patience 10 --min_delta 0.001 --loss_function TverskyLoss --mode train
# Out:
# wandb: Currently logged in as: arthur12137. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /mnt/vos-9k0sd0n7/will/bowen_workplace/Oil_Seep_Test/wandb/run-20241011_044249-12gdc677
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run proud-donkey-115
# wandb: ⭐️ View project at https://wandb.ai/arthur12137/unet-seep-detection
# wandb: 🚀 View run at https://wandb.ai/arthur12137/unet-seep-detection/runs/12gdc677
# INFO:root:[EPOCH 1] Train Loss: 0.9199 | Dice: 0.1765 | IoU: 0.0454 | Precision: 0.6590 | Recall: 0.3981 | F1: 0.1058 | Accuracy: 0.8673
# [EPOCH 1] Train Loss: 0.9199 | Dice: 0.1765 | IoU: 0.0454 | Precision: 0.6590 | Recall: 0.3981 | F1: 0.1058 | Accuracy: 0.8673
# INFO:root:[EPOCH 1] Valid Loss: 0.8861 | Dice: 0.0040 | IoU: 0.0031 | Precision: 0.9469 | Recall: 0.0034 | F1: 0.0034 | Accuracy: 0.9820
# ...

# %%
# !python3 main.py --epochs 300 --lr 0.001 --patience 10 --min_delta 0.001 --loss_function CrossEntropyLoss --mode eval
# Out:
# wandb: Currently logged in as: arthur12137. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /mnt/vos-9k0sd0n7/will/bowen_workplace/Oil_Seep_Test/wandb/run-20241011_041137-xv2kd6wc
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run stilted-vortex-100
# wandb: ⭐️ View project at https://wandb.ai/arthur12137/unet-seep-detection
# wandb: 🚀 View run at https://wandb.ai/arthur12137/unet-seep-detection/runs/xv2kd6wc
# ...
